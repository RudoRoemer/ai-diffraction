# %%
import pandas as pd

# %%
df1 = pd.read_csv("../notebooks/space_groups.csv")
df1
# Out:
#        ICSD_code space_group
# 0           1000    F m -3 m
# 1         100018    P -4 3 n
# 2          10009    F -4 3 m
# 3         100098       I 2 3
# 4         100099       I 2 3
# ...          ...         ...
# 12449       9988    F 41 3 2
# 12450      99963    P m -3 m
# 12451      99964    P m -3 m
# 12452      99965    P m -3 m
# 12453      99996    I -4 3 d
#
# [12454 rows x 2 columns]

# %%
df2 = pd.read_csv("Cubic CIFs/metadata.csv")
df2
# Out:
#        index  ICSD_code chemical_formula_sum  cell_length space_group
# 0          0     106924              Al1 Np3      4.26900    P m -3 m
# 1          1     106925              In1 Np3      4.61500    P m -3 m
# 2          2     106935          Pd0.9 Rh0.1      3.88120    F m -3 m
# 3          3     106936          Ni0.1 Pd0.9      3.86600    F m -3 m
# 4          4     106937  Co0.05 Pd0.9 Rh0.05      3.87600    F m -3 m
# ...      ...        ...                  ...          ...         ...
# 21596  21596     149274    Ba1 Na1 O12 P3 Y2     10.19120      P 21 3
# 21597  21597     149277      N0.58 O0.42 Ti1      4.22990    F m -3 m
# 21598  21598     149278      N0.75 O0.25 Ti1      4.23500    F m -3 m
# 21599  21599     149279      N0.72 O0.28 Ti1      4.23489    F m -3 m
# 21600  21600     149280      N0.87 O0.13 Ti1      4.23630    F m -3 m
#
# [21601 rows x 5 columns]

# %%
print(df1['space_group'].isin(df2['space_group']).value_counts())
# Out:
# space_group
# True     12446
# False        8
# Name: count, dtype: int64

# %%
df1.groupby(["space_group"]).size()
# Out:
# space_group
# F -4 3 c        68
# F -4 3 m       493
# F 2 3           40
# F 4 3 2          8
# F 41 3 2         6
# F d -3 S         8
# F d -3 Z       189
# F d -3 c Z      69
# F d -3 m S     455
# F d -3 m Z    3209
# F m -3          78
# F m -3 c       334
# F m -3 m       493
# I -4 3 d       486
# I -4 3 m       482
# I 2 3          169
# I 21 3         102
# I 4 3 2          3
# I 41 3 2        49
# I a -3         438
# I a -3 d       847
# I m -3         686
# I m -3 m       541
# P -4 3 m       240
# P -4 3 n       456
# P 2 3           25
# P 21 3         199
# P 4 3 2          1
# P 41 3 2       220
# P 42 3 2         8
# P 43 3 2       161
# P a -3         484
# P m -3         128
# P m -3 m       488
# P m -3 n       496
# P n -3 S        27
# P n -3 Z       110
# P n -3 m S      33
# P n -3 m Z     105
# P n -3 n Z      20
# dtype: int64

# %%
df2.groupby(["space_group"]).size()
# Out:
# space_group
# F -4 3 c        42
# F -4 3 m      1395
# F 2 3           44
# F 4 3 2          9
# F 41 3 2         3
# F d -3 S         2
# F d -3 Z        94
# F d -3 c Z      51
# F d -3 m S     968
# F d -3 m Z    5197
# F m -3          50
# F m -3 c       220
# F m -3 m      4170
# I -4 3 d       425
# I -4 3 m       551
# I 2 3          111
# I 21 3          64
# I 4 3 2          2
# I 41 3 2        37
# I a -3         373
# I a -3 d       953
# I m -3         918
# I m -3 m       408
# P -4 3 m       126
# P -4 3 n       336
# P 2 3           24
# P 21 3         513
# P 4 3 2          1
# P 41 3 2       185
# P 43 3 2       159
# P a -3         407
# P m -3          63
# P m -3 m      2696
# P m -3 n       782
# P n -3 S        10
# P n -3 Z       103
# P n -3 m S       5
# P n -3 m Z      84
# P n -3 n S       1
# P n -3 n Z      19
# dtype: int64

# %%
count = 0
for row in df2.iterrows():
    ICSD_code = row[1]["ICSD_code"]
    print(df1['ICSD_code'].isin(df1['your_column_name']).value_counts())
    # ICSD_code = df2[]df
# Out:
# 106924
# 106925
# 106935
# 106936
# 106937
# 106938
# 106939
# 107006
# 107007
# 107033
# 107036
# 109012
# 109559
# 110134
# 117088
# 117089
# 117090
# 117091
# 117092
# 117093
# 117094
# 117095
# 117096
# 117097
# 117098
# 117099
# 117136
# 118582
# 118583
# 118584
# 118585
# 118586
# 119243
# 119244
# 119245
# 119246
# 119247
# 119248
# 119249
# 119250
# 119345
# 150191
# 150198
# 150206
# 150207
# 150208
# 150209
# 150210
# 150211
# 150212
# 150233
# 150234
# 150236
# 150237
# 150238
# 150239
# 150240
# 150241
# 150242
# 150802
# 150803
# 159908
# 163042
# 166507
# 170748
# 170752
# 190224
# 190225
# 236973
# 236974
# 236975
# 236976
# 240021
# 240025
# 240037
# 240038
# 248459
# 248469
# 260147
# 280190
# 280301
# 280304
# 280320
# 280321
# 280322
# 280323
# 280370
# 280374
# 280375
# 280390
# 280398
# 280399
# 280400
# 280401
# 280417
# 280418
# 280419
# 280424
# 280513
# 280547
# 280548
# 280549
# 280550
# 280551
# 280552
# 280553
# 280554
# 290808
# 290809
# 290810
# 290811
# ...
